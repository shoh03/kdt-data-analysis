# %% [markdown]
# # 케글 HR 이직 데이터 셋
# - IBM HR Analytics Employee Attrition & Performance 데이터셋은 기업 내 직원들의 인적 사항, 직무 만족도, 근무 환경 및 수당 등의 정보를 바탕으로 직원의 이직 여부(Attrition)를 분석하고 예측하기 위해 수집된 데이터입니다. 인사 관리자(HR)가 직원들의 이탈 원인을 파악하고 조직 만족도와 인재 유지율을 높이기 위한 비즈니스 인사이트를 도출하는 EDA 및 머신러닝 과제에 자주 활용됩니다.
#
# - [IBM HR Analytics Employee Attrition & Performance](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset)
#
# ## 데이터셋 표
# | 컬럼명 | 설명 | 데이터 형태 | 데이터 타입 |
# | :--- | :--- | :--- | :--- |
# | Attrition(타겟) | 이직 여부 (Yes/No) | 범주형 (Categorical) | object / string |
# | Age | 직원 연령 | 수치형 (Numerical) | int |
# | Gender | 성별 (Male/Female) | 범주형 (Categorical) | object / string |
# | MaritalStatus | 결혼 여부 (Single, Married, Divorced) | 범주형 (Categorical) | object / string |
# | Education | 학력 수준 (1: 이하 ~ 5: 박사) | 범주형 (Categorical) | int |
# | Department | 근무 부서 | 범주형 (Categorical) | object / string |
# | JobRole | 세부 직무 | 범주형 (Categorical) | object / string |
# | BusinessTravel | 출장 빈도 | 범주형 (Categorical) | object / string |
# | OverTime | 야근 여부 (Yes/No) | 범주형 (Categorical) | object / string |
# | DistanceFromHome | 출퇴근 거리 | 수치형 (Numerical) | int |
# | MonthlyIncome | 월소득 | 수치형 (Numerical) | int |
# | PercentSalaryHike | 전년 대비 인상률 (%) | 수치형 (Numerical) | int |
# | StockOptionLevel | 스톡옵션 등급 (0~3) | 범주형 (Categorical) | int |
# | TotalWorkingYears | 총 경력 연수 | 수치형 (Numerical) | int |
# | YearsAtCompany | 현 회사 근속 연수 | 수치형 (Numerical) | int |
# | EnvironmentSatisfaction | 근무 환경 만족도 (1~4) | 범주형 (Categorical) | int |
# | JobSatisfaction | 직무 만족도 (1~4) | 범주형 (Categorical) | int |
# | WorkLifeBalance | 워라밸 만족도 (1~4) | 범주형 (Categorical) | int |
# | YearsSinceLastPromotion | 마지막 승진 후 기간 | 수치형 (Numerical) | int |

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 윈도우 맑은 고딕 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
base_path = r"C:\kdt_0900_osh\data_analysis\resource\dataset"
file_name = r"hr_employee_attrition.csv"

file_path = os.path.join(base_path, file_name)

hr_df = pd.read_csv(file_path)
hr_df
# Out:
#      Attrition  Age  Gender MaritalStatus  Education              Department  \
# 0          Yes   41  Female        Single          2                   Sales
# 1           No   49    Male       Married          1  Research & Development
# 2          Yes   37    Male        Single          2  Research & Development
# 3           No   33  Female       Married          4  Research & Development
# 4           No   27    Male       Married          1  Research & Development
# ...        ...  ...     ...           ...        ...                     ...
# 1465        No   36    Male       Married          2  Research & Development
# 1466        No   39    Male       Married          1  Research & Development
# 1467        No   27    Male       Married          3  Research & Development
# 1468        No   49    Male       Married          3                   Sales
# 1469        No   34    Male       Married          3  Research & Development
#
#                         JobRole     BusinessTravel OverTime  DistanceFromHome  \
# 0               Sales Executive      Travel_Rarely      Yes                 1
# 1            Research Scientist  Travel_Frequently       No                 8
# 2         Laboratory Technician      Travel_Rarely      Yes                 2
# 3            Research Scientist  Travel_Frequently      Yes                 3
# 4         Laboratory Technician      Travel_Rarely       No                 2
# ...                         ...                ...      ...               ...
# 1465      Laboratory Technician  Travel_Frequently       No                23
# 1466  Healthcare Representative      Travel_Rarely       No                 6
# 1467     Manufacturing Director      Travel_Rarely      Yes                 4
# 1468            Sales Executive  Travel_Frequently       No                 2
# 1469      Laboratory Technician      Travel_Rarely       No                 8
#
#       MonthlyIncome  PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0              5993                 11                 0                  8
# 1              5130                 23                 1                 10
# 2              2090                 15                 0                  7
# 3              2909                 11                 0                  8
# 4              3468                 12                 1                  6
# ...             ...                ...               ...                ...
# 1465           2571                 17                 1                 17
# 1466           9991                 15                 1                  9
# 1467           6142                 20                 1                  6
# 1468           5390                 14                 0                 17
# 1469           4404                 12                 0                  6
#
#       YearsAtCompany  EnvironmentSatisfaction  JobSatisfaction  \
# 0                  6                        2                4
# 1                 10                        3                2
# 2                  0                        4                3
# 3                  8                        4                3
# 4                  2                        1                2
# ...              ...                      ...              ...
# 1465               5                        3                4
# 1466               7                        4                1
# 1467               6                        2                2
# 1468               9                        4                2
# 1469               4                        2                3
#
#       WorkLifeBalance  PerformanceRating  YearsSinceLastPromotion
# 0                   1                  3                        0
# 1                   3                  4                        1
# 2                   3                  3                        0
# 3                   3                  3                        3
# 4                   3                  3                        2
# ...               ...                ...                      ...
# 1465                3                  3                        0
# 1466                3                  3                        1
# 1467                3                  4                        0
# 1468                2                  3                        0
# 1469                4                  3                        1
#
# [1470 rows x 20 columns]

# %%
hr_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Attrition                1470 non-null   str
#  1   Age                      1470 non-null   int64
#  2   Gender                   1470 non-null   str
#  3   MaritalStatus            1470 non-null   str
#  4   Education                1470 non-null   int64
#  5   Department               1470 non-null   str
#  6   JobRole                  1470 non-null   str
#  7   BusinessTravel           1470 non-null   str
#  8   OverTime                 1470 non-null   str
#  9   DistanceFromHome         1470 non-null   int64
#  10  MonthlyIncome            1470 non-null   int64
#  11  PercentSalaryHike        1470 non-null   int64
#  12  StockOptionLevel         1470 non-null   int64
#  13  TotalWorkingYears        1470 non-null   int64
#  14  YearsAtCompany           1470 non-null   int64
#  15  EnvironmentSatisfaction  1470 non-null   int64
#  16  JobSatisfaction          1470 non-null   int64
#  17  WorkLifeBalance          1470 non-null   int64
#  18  PerformanceRating        1470 non-null   int64
#  19  YearsSinceLastPromotion  1470 non-null   int64
# dtypes: int64(13), str(7)
# memory usage: 229.8 KB
# (1470, 20)

# %%
hr_df.describe()
# Out:
#                Age    Education  DistanceFromHome  MonthlyIncome  \
# count  1470.000000  1470.000000       1470.000000    1470.000000
# mean     36.923810     2.912925          9.192517    6502.931293
# std       9.135373     1.024165          8.106864    4707.956783
# min      18.000000     1.000000          1.000000    1009.000000
# 25%      30.000000     2.000000          2.000000    2911.000000
# 50%      36.000000     3.000000          7.000000    4919.000000
# 75%      43.000000     4.000000         14.000000    8379.000000
# max      60.000000     5.000000         29.000000   19999.000000
#
#        PercentSalaryHike  StockOptionLevel  TotalWorkingYears  YearsAtCompany  \
# count        1470.000000       1470.000000        1470.000000     1470.000000
# mean           15.209524          0.793878          11.279592        7.008163
# std             3.659938          0.852077           7.780782        6.126525
# min            11.000000          0.000000           0.000000        0.000000
# 25%            12.000000          0.000000           6.000000        3.000000
# 50%            14.000000          1.000000          10.000000        5.000000
# 75%            18.000000          1.000000          15.000000        9.000000
# max            25.000000          3.000000          40.000000       40.000000
#
#        EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# count              1470.000000      1470.000000      1470.000000
# mean                  2.721769         2.728571         2.761224
# std                   1.093082         1.102846         0.706476
# min                   1.000000         1.000000         1.000000
# 25%                   2.000000         2.000000         2.000000
# 50%                   3.000000         3.000000         3.000000
# 75%                   4.000000         4.000000         3.000000
# max                   4.000000         4.000000         4.000000
#
#        PerformanceRating  YearsSinceLastPromotion
# count        1470.000000              1470.000000
# mean            3.153741                 2.187755
# std             0.360824                 3.222430
# min             3.000000                 0.000000
# 25%             3.000000                 0.000000
# 50%             3.000000                 1.000000
# 75%             3.000000                 3.000000
# max             4.000000                15.000000

# %%
hr_df[hr_df["MonthlyIncome"]==19999]
# Out:
#     Attrition  Age Gender MaritalStatus  Education              Department  \
# 190        No   52   Male       Married          4  Research & Development
#
#      JobRole BusinessTravel OverTime  DistanceFromHome  MonthlyIncome  \
# 190  Manager  Travel_Rarely       No                 1          19999
#
#      PercentSalaryHike  StockOptionLevel  TotalWorkingYears  YearsAtCompany  \
# 190                 14                 1                 34              33
#
#      EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 190                        3                3                3
#
#      PerformanceRating  YearsSinceLastPromotion
# 190                  3                       11

# %% [markdown]
# #### 야근(OverTime)을 하는 직원과 야근을 하지 않는 직원의 이직률 차이가 얼마나 나는지 비교하고 결과를 서술하세요.
# - 범주형 vs 범주형 데이터

# %%
# .crosstab()
# normalize= : 값을 백분율로 만들어줌
overtime_attrition = (
    pd.crosstab(hr_df["OverTime"],hr_df["Attrition"], normalize="index")* 100
)

print("야근 여부에 따른 이직 비율")
overtime_attrition
# Out:
# 야근 여부에 따른 이직 비율
# Attrition         No        Yes
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %%
overtime_rate = hr_df.groupby("OverTime")["Attrition"].apply(lambda x: (x == "Yes").mean() * 100)
overtime_rate
# Out:
# OverTime
# No     10.436433
# Yes    30.528846
# Name: Attrition, dtype: float64

# %%
ax = overtime_attrition.plot(kind='bar', stacked=True)
plt.title("야근 여부에 따른 이직 비율(%)")
plt.ylabel("이직 비율(%)")
plt.xlabel("야근 여부")
plt.xticks(rotation=0)
plt.show()

"""
    **tip** 범주형과 범주형 데이터를 비교할 때, Bar 차트가 적합
    야근을 하는 직원의 이직률이 야근을 하지 않는 직원의 이직률보다 약 20% 더 높다.
"""
None

# %% [markdown]
# ## 2번
# - 이직한 직원(Attrition = Yes)과 잔류한 직원(No)의 월소득(MonthlyIncome) 평균 및 분포 차이 비교(boxplot 추천)
# - boxplot: 수치형(연속형) 데이터의 분포를 확인, 두 집단 간의 치우침 또는 중심 위치 비교에 용이함.

# %%
print("이직 여부별 월 소득 기술통계량")

income_state = hr_df.groupby("Attrition")["MonthlyIncome"].agg(["count","mean","median","min","max","std"])
income_state
# Out:
# 이직 여부별 월 소득 기술통계량
#            count         mean  median   min    max          std
# Attrition
# No          1233  6832.739659  5204.0  1051  19999  4818.208001
# Yes          237  4787.092827  3202.0  1009  19859  3640.210367

# %%
plt.figure(figsize=(6,5))

sns.boxplot(data=hr_df, x="Attrition", y="MonthlyIncome")
plt.xlabel("이직 여부")
plt.ylabel("월 소득($)")

plt.show()

"""
    잔류자의 월 평균 소득(6832$)은 이직자의 월평균 소득(4787$)보다 약 2000$ 이상 높으며, 이직자는 저소득 구간에 몰려있다.
    따라서 월급은 이직에 영향을 주지 않았을까?
"""
None

# %% [markdown]
# ## 3번
# - 가설: 마지막 승진 후 기간(YearsSinceLastPromotion)이 길어질수록 이직률이 더 높아질까?
# - 검증: 연속형(순서형) 데이터의 시각화 -> 라인차트 권장

# %%
hr_df["YearsSinceLastPromotion"]
hr_df["Attrition"]
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: str

# %%
hr_df.groupby("Attrition")["YearsSinceLastPromotion"].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# Attrition
# No         1233.0  2.234388  3.234762  0.0  0.0  1.0  3.0  15.0
# Yes         237.0  1.945148  3.153077  0.0  0.0  1.0  2.0  15.0

# %%
lastpro_attrition = hr_df.groupby("Attrition")["YearsSinceLastPromotion"].agg(["mean","median","max","min"])
lastpro_attrition
# Out:
#                mean  median  max  min
# Attrition
# No         2.234388     1.0   15    0
# Yes        1.945148     1.0   15    0

# %%
plt.plot(list(sorted(hr_df[hr_df["Attrition"] == "Yes"]["YearsSinceLastPromotion"])))

# %%
plt.plot(list(sorted(hr_df[hr_df["Attrition"] == "No"]["YearsSinceLastPromotion"])))

# %%
plt.figure(figsize=(10,5))

sns.lineplot(data=hr_df,x="YearsSinceLastPromotion", y="Attrition")
plt.xlabel("이직 여부")
plt.ylabel("마지막 승진으로부터 경과된 년수")
# Out:
# Text(0, 0.5, '마지막 승진으로부터 경과된 년수')

# %%
for yn in ["Yes","No"]:
    plt.plot(

# %%
hr_df.groupby("Attrition")["YearsSinceLastPromotion"].mean()
# Out:
# Attrition
# No     2.234388
# Yes    1.945148
# Name: YearsSinceLastPromotion, dtype: float64

# %%
dictionary = {"Yes":list(sorted(hr_df[hr_df["Attrition"] == "Yes"]["YearsSinceLastPromotion"])), "No":list(sorted(hr_df[hr_df["Attrition"] == "No"]["YearsSinceLastPromotion"]))}

# %%
hr_df[hr_df["Attrition"] == "Yes"]["YearsSinceLastPromotion"]
# Out:
# 0       0
# 2       0
# 14      0
# 21      0
# 24      1
#        ..
# 1438    1
# 1442    2
# 1444    9
# 1452    0
# 1461    2
# Name: YearsSinceLastPromotion, Length: 237, dtype: int64

# %% [markdown]
# ---

# %%
promo_df = hr_df.groupby("YearsSinceLastPromotion")["Attrition"].agg(
    YesRate=lambda x: (x == "Yes").mean() * 100,
    NoRate=lambda x: (x == "No").mean() * 100,
).reset_index()

promo_df
# Out:
#     YearsSinceLastPromotion    YesRate      NoRate
# 0                         0  18.932874   81.067126
# 1                         1  13.725490   86.274510
# 2                         2  16.981132   83.018868
# 3                         3  17.307692   82.692308
# 4                         4   8.196721   91.803279
# 5                         5   4.444444   95.555556
# 6                         6  18.750000   81.250000
# 7                         7  21.052632   78.947368
# 8                         8   0.000000  100.000000
# 9                         9  23.529412   76.470588
# 10                       10  16.666667   83.333333
# 11                       11   8.333333   91.666667
# 12                       12   0.000000  100.000000
# 13                       13  20.000000   80.000000
# 14                       14  11.111111   88.888889
# 15                       15  23.076923   76.923077

# %%
plt.figure(figsize=(5,4))
plt.plot(promo_df["YearsSinceLastPromotion"], promo_df["YesRate"], color="red", label="이직(Yes)")
plt.plot(promo_df["YearsSinceLastPromotion"], promo_df["NoRate"], color="green", label="유지(NO)")
plt.title("마지막 승진 후 기간별 이직률 vs 유지율(%)")
plt.xlabel("마지막 승진 후 경과된 기간")
plt.ylabel("비율(%)")
plt.axvline(3, alpha=0.2, linestyle='--')
plt.axvline(6, alpha=0.2, linestyle='--')
plt.axvline(9, alpha=0.2, linestyle='--')
plt.legend()
plt.show()

"""
    - 승진 직후 0년차에 약 18.9% 정도의 이직률을 갖는다.
    - 승진 경력의 타이틀을 확보한 직원이 몸값을 올려서 이직하지 않을까?
    - 1~2년 승진을 못하면 승진을 포기하고 이직을 하는 비율도 생각보다 높게 나타났다.
    - 장기화 7년차(21%) 이후부터는 다시 이직률이 낮아지는(0%) 역전 현상이 발생하고 있다.(데이터 부족)
    - 승진 후 기간이 길어질수록 이직률이 높아진다 -> 부분 기각
"""
None

# %% [markdown]
# ## 4번
# - 워라밸 만족도(WorkLifeBalance) 1~4점 점수별 이직률 구하고, 워라밸 1점의 이직 위험도를 분석하기
# - 범주형끼리 비교 -> bar chart 추천

# %%
wlb_df = hr_df.groupby("WorkLifeBalance")["Attrition"].apply(
    lambda x: (x == "Yes").mean()
    ).reset_index()

wlb_df
# Out:
#    WorkLifeBalance  Attrition
# 0                1   0.312500
# 1                2   0.168605
# 2                3   0.142217
# 3                4   0.176471

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=wlb_df, x="WorkLifeBalance", y="Attrition", hue="WorkLifeBalance", palette=["red","orange","green","blue"])
plt.ylim(0,0.5)
plt.title("워라밸 점수별 이직률(%)")
plt.xlabel("만족도 점수(0~4)")
plt.ylabel("이직률(%)", rotation=0)
plt.show()

"""
    워라밸 1점(Bad) 직원 이직률은 31%, 2~4점 그룹 이직률 평균인 15% 대비 2배 이상의 이직 위험도를 보인다.
    야근을 많이하게 되는 이유(사수의 부조리, 과중한 업무, 업무량을 검토해볼 필요성이 보인다.
"""

# %%
hr_df[(hr_df["WorkLifeBalance"] == 1) & (hr_df["Attrition"] == "Yes")].count() / hr_df[hr_df["WorkLifeBalance"] == 1].count()
# Out:
# Attrition                  0.3125
# Age                        0.3125
# Gender                     0.3125
# MaritalStatus              0.3125
# Education                  0.3125
# Department                 0.3125
# JobRole                    0.3125
# BusinessTravel             0.3125
# OverTime                   0.3125
# DistanceFromHome           0.3125
# MonthlyIncome              0.3125
# PercentSalaryHike          0.3125
# StockOptionLevel           0.3125
# TotalWorkingYears          0.3125
# YearsAtCompany             0.3125
# EnvironmentSatisfaction    0.3125
# JobSatisfaction            0.3125
# WorkLifeBalance            0.3125
# PerformanceRating          0.3125
# YearsSinceLastPromotion    0.3125
# dtype: float64
